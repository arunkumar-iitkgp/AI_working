# %% [markdown]
# <a href="https://colab.research.google.com/github/arunkumar-iitkgp/AI_working/blob/main/good.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
model = torchvision.models.resnet18(weights='DEFAULT')
import torchvision.transforms as transforms
preprocess = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
        ),
    ]
)

from PIL import Image

# Replace with the actual path to your image file
img = Image.open('pencil.jpg')
img_preprocessed = preprocess(img)
model.eval()
with torch.no_grad():
    outputs = model(img_preprocessed.unsqueeze(0))
_, predicted = torch.max(outputs, 1)
print(f"Predicted Class Index: {predicted.item() + 1}")
import json
import urllib.request

url = "https://raw.githubusercontent.com/anishathalye/imagenet-simple-labels/master/imagenet-simple-labels.json"
urllib.request.urlretrieve(url, "imagenet-simple-labels.json")

with open("imagenet-simple-labels.json") as f:
    class_idx = json.load(f)

predicted_index = predicted.item()
label = class_idx[predicted_index]
print(f"The label for index {predicted_index + 1} is: {label}")
# Out:
# Predicted Class Index: 711
# The label for index 711 is: pencil sharpener
